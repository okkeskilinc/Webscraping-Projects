# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def transform(data):
    transformed_data=(data-32)/1.8
    return transformed_data

# %%
url="https://weather.com/weather/tenday/l/33d1e415eb66f3e1ab35c3add45fccf4512715d329edbd91c806a6957e123b49"
html_data=requests.get(url)
html_data
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(html_data.content,"html.parser")

# %%
ten_day=soup.find(class_="DailyForecast--DisclosureList--msYIJ")
forecast_items=ten_day.find_all(class_="Disclosure--themeList--25Q0H")
to_day=forecast_items[0]
print(to_day.prettify())
# Out:
# <details class="Disclosure--themeList--25Q0H" data-track-string="false" id="detailIndex0" open="">
#  <summary aria-expanded="true" class="Disclosure--Summary--UuybP DaypartDetails--Summary--3IBUr Disclosure--positionShowOpenSummaryContainer--Qou6d Disclosure--hideBorderOnSummaryOpen--ZdSDc" role="button">
#   <div class="DaypartDetails--DetailSummaryContent--3uxcj Disclosure--SummaryDefault--3xAWB Disclosure--positionShowOpenSummary--C1hiI">
#    <div class="Accessibility--visuallyHidden--2uGW3">
#     <div class="DetailsSummary--DetailsSummary--2HluQ DetailsSummary--fadeOnOpen--vFCc_" data-testid="DetailsSummary" id="titleIndex0">
#      <h2 class="DetailsSummary--daypartName--2FBp2" data-testid="daypartName">
#       Tonight
#      </h2>
#      <div class="DetailsSummary--temperature--1Syw3" data-testid="detailsTemperature">
#       <span class="DetailsSummary--highTempValue--3Oteu" data-testid="TemperatureValue">
#        --
#       </span>
#       <span data-testid="lowTempValue">
#        /
#        <span class="DetailsSummary--lowTempValue--3H-7I" data-testid="TemperatureValue">
#         46°
#        </span>
#       </span>
#      </div>
#      <div class="DetailsSummary--condition--24gQw" data-testid="wxIcon">
#       <svg aria-hidden="true" class="DetailsSummary--wxIcon--1eiMv Icon--icon--3wCKh Icon--fullTheme--3ns8p" data-testid="Icon" role="img" set="weather" skycode="33" theme="full" viewbox="0 0 200 200">
#        <title>
#         Mostly Clear Night
#        </title>
#        <use mask="url(#mostly-clear-night-mask)" transform="matrix(2.05 0 0 2.05 -61.5 4.1)" xlink:href="#svg-symbol-moon">
#        </use>
#        <use transform="matrix(.56 0 0 .56 52.08 42.56)" xlink:href="#svg-symbol-cloud">
#        </use>
#       </svg>
#       <span class="DetailsSummary--extendedData--365A_">
#        Mostly Clear
#       </span>
#      </div>
#      <div class="DetailsSummary--precip--1ecIJ" data-testid="Precip">
#       <svg aria-hidden="false" aria-label="Chance of Rain" class="DetailsSummary--precipIcon--3mKHx Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="precip-rain-single" role="img" set="heads-up" theme="action" viewbox="0 -2 5 10">
#        <title>
#         Rain
#        </title>
#        <path d="M4.7329.0217c-.1848-.059-.3855.0064-.4803.148L.2731 5.1191c-.0814.0922-.1501.1961-.196.3108-.2469.6009.1185 1.2697.8156 1.4943.6914.226 1.447-.0712 1.7-.6585L4.9662.4987l.0111-.0282c.073-.1807-.036-.379-.2444-.4488z">
#        </path>
#       </svg>
#       <span data-testid="PercentageValue">
#        10%
#       </span>
#      </div>
#      <div class="DetailsSummary--wind--2rkTO DetailsSummary--extendedData--365A_" data-testid="wind">
#       <svg aria-hidden="false" aria-label="Wind" class="DetailsSummary--conditionsIcon--1P-Au Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="wind" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#        <title>
#         Wind
#        </title>
#        <path d="M6 8.67h5.354c1.457 0 2.234-1.158 2.234-2.222S12.687 4.4 11.354 4.4c-.564 0-1.023.208-1.366.488M3 11.67h15.54c1.457 0 2.235-1.158 2.235-2.222S19.873 7.4 18.54 7.4c-.747 0-1.311.365-1.663.78M6 15.4h9.389c1.457 0 2.234 1.159 2.234 2.223 0 1.064-.901 2.048-2.234 2.048a2.153 2.153 0 0 1-1.63-.742" fill="none" stroke="currentColor" stroke-linecap="round" stroke-width="2">
#        </path>
#       </svg>
#       <span class="Wind--windWrapper--3aqXJ undefined" data-testid="Wind">
#        SSW
#        <!-- -->
#        6 mph
#       </span>
#      </div>
#     </div>
#    </div>
#    <svg aria-hidden="true" class="Disclosure--SummaryIcon--1kGJk Icon--icon--3wCKh" data-testid="Icon" name="caret-up" role="img" set="ui" viewbox="0 0 24 24">
#     <title>
#      Arrow Up
#     </title>
#     <path d="M12 8.914l7.293 7.293a1 1 0 1 0 1.414-1.414l-8-8a1 1 0 0 0-1.414 0l-8 8a1 1 0 1 0 1.414 1.414L12 8.914z">
#     </path>
#    </svg>
#   </div>
#  </summary>
#  <div class="DaypartDetails--Content--hJ52O DaypartDetails--contentGrid--1SWty">
#   <div class="DailyContent--DailyContent--KcPxD" data-testid="DailyContent">
#    <h3 class="DailyContent--daypartName--1bzYn">
#     <span class="DailyContent--daypartDate--2A3Wi">
#      Sun 21
#     </span>
#     | Night
#    </h3>
#    <div class="DailyContent--ConditionSummary--1X5kT" data-testid="ConditionsSummary">
#     <div>
#      <span class="DailyContent--temp--3d4dn" data-testid="TemperatureValue">
#       46°
#      </span>
#     </div>
#     <div class="DailyContent--Condition--bQKA2" data-testid="weatherIcon">
#      <svg aria-hidden="false" aria-label="Mostly Clear" class="DailyContent--weatherIcon--3zguJ Icon--icon--3wCKh Icon--fullTheme--3ns8p" data-testid="Icon" role="img" set="weather" skycode="33" theme="full" viewbox="0 0 200 200">
#       <title>
#        Mostly Clear Night
#       </title>
#       <use mask="url(#mostly-clear-night-mask)" transform="matrix(2.05 0 0 2.05 -61.5 4.1)" xlink:href="#svg-symbol-moon">
#       </use>
#       <use transform="matrix(.56 0 0 .56 52.08 42.56)" xlink:href="#svg-symbol-cloud">
#       </use>
#      </svg>
#     </div>
#     <div class="DailyContent--dataPoints--1Nya6">
#      <div class="DailyContent--label--3Ok7H">
#       <div class="DailyContent--rainIconBlock--NoXMg">
#        <svg aria-hidden="false" aria-label="Chance of Rain" class="DailyContent--rainIcon--2NdTM Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="precip-rain-single" role="img" set="heads-up" theme="action" viewbox="0 -2 5 10">
#         <title>
#          Rain
#         </title>
#         <path d="M4.7329.0217c-.1848-.059-.3855.0064-.4803.148L.2731 5.1191c-.0814.0922-.1501.1961-.196.3108-.2469.6009.1185 1.2697.8156 1.4943.6914.226 1.447-.0712 1.7-.6585L4.9662.4987l.0111-.0282c.073-.1807-.036-.379-.2444-.4488z">
#         </path>
#        </svg>
#       </div>
#       <span class="DailyContent--value--37sk2" data-testid="PercentageValue">
#        10%
#       </span>
#      </div>
#      <div class="DailyContent--label--3Ok7H">
#       <svg aria-hidden="true" arialabel="Wind" class="DailyContent--windIcon--2qFiv Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="wind" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#        <title>
#         Wind
#        </title>
#        <path d="M6 8.67h5.354c1.457 0 2.234-1.158 2.234-2.222S12.687 4.4 11.354 4.4c-.564 0-1.023.208-1.366.488M3 11.67h15.54c1.457 0 2.235-1.158 2.235-2.222S19.873 7.4 18.54 7.4c-.747 0-1.311.365-1.663.78M6 15.4h9.389c1.457 0 2.234 1.159 2.234 2.223 0 1.064-.901 2.048-2.234 2.048a2.153 2.153 0 0 1-1.63-.742" fill="none" stroke="currentColor" stroke-linecap="round" stroke-width="2">
#        </path>
#       </svg>
#       <span class="Wind--windWrapper--3aqXJ DailyContent--value--37sk2" data-testid="Wind">
#        SSW
#        <!-- -->
#        6 mph
#       </span>
#      </div>
#     </div>
#    </div>
#    <p class="DailyContent--narrative--hplRl" data-testid="wxPhrase">
#     Mainly clear skies. Low 46F. Winds SSW at 5 to 10 mph.
#    </p>
#   </div>
#   <ul class="DetailsTable--DetailsTable--142jU DaypartDetails--DetailsTable--2VLwj" data-testid="DetailsTable">
#    <li class="DetailsTable--listItem--2yVyz" data-testid="HumiditySection">
#     <svg aria-hidden="true" class="DetailsTable--icon--1FR4N Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="humidity" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#      <title>
#       Humidity
#      </title>
#      <path d="M11.743 17.912a4.182 4.182 0 0 1-2.928-1.182 3.972 3.972 0 0 1-.614-4.962.743.743 0 0 1 .646-.349c.234 0 .476.095.66.275l4.467 4.355c.385.376.39.998-.076 1.275a4.216 4.216 0 0 1-2.155.588M11.855 4c.316 0 .61.14.828.395.171.2.36.416.562.647 1.857 2.126 4.965 5.684 4.965 8.73 0 3.416-2.85 6.195-6.353 6.195-3.505 0-6.357-2.78-6.357-6.195 0-3.082 2.921-6.406 4.854-8.605.242-.275.47-.535.673-.772A1.08 1.08 0 0 1 11.855 4" fill-rule="evenodd">
#      </path>
#     </svg>
#     <div class="DetailsTable--field--3ZKJV">
#      <span class="DetailsTable--label--3Va-t" data-testid="HumidityTitle">
#       Humidity
#      </span>
#      <span class="DetailsTable--value--1q_qD" data-testid="PercentageValue">
#       84%
#      </span>
#     </div>
#    </li>
#    <li class="DetailsTable--listItem--2yVyz" data-testid="uvIndexSection">
#     <svg aria-hidden="true" class="DetailsTable--icon--1FR4N Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="uv" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#      <title>
#       UV Level
#      </title>
#      <path d="M7.4 5.598a.784.784 0 0 1 .25-.92c.335-.256.824-.197 1.02.062.066.063.066.063.08.085l2.406 3.152-.626.238a3.983 3.983 0 0 0-1.097.633l-.522.424L7.4 5.598zm4.539 2.358c-.21 0-.418.017-.625.05l-.664.106.09-.666.438-3.266c.013-.072.013-.072.012-.057a.783.783 0 0 1 .666-.616.78.78 0 0 1 .872.639l.006.038.507 3.933-.662-.108a3.957 3.957 0 0 0-.64-.053zm-7.781 3.19l.026-.004 3.934-.507-.108.662a3.98 3.98 0 0 0-.003 1.266l.105.664-.665-.09-3.265-.439a.784.784 0 0 1-.676-.679c-.054-.42.238-.809.63-.869l.022-.004zm11.504-.617a3.98 3.98 0 0 0-.632-1.097l-.425-.522.623-.256 3.056-1.256a.787.787 0 0 1 .916.253c.256.337.199.817-.104 1.063l-.045.037-3.151 2.405-.238-.627zm-1.205-1.672a3.984 3.984 0 0 0-1.095-.637l-.626-.24.41-.532 2.008-2.602c.059-.07.059-.07.046-.052a.78.78 0 0 1 1.306.227c.076.185.079.39.02.54l-.021.06-1.528 3.662-.52-.426zM4.595 7.793c.162-.387.611-.58.971-.441.017.004.017.004.055.02L9.283 8.9l-.425.52a3.985 3.985 0 0 0-.636 1.094l-.24.627-3.144-2.425a.784.784 0 0 1-.243-.924zm14.443 7.367c.054.045.054.045.044.04a.784.784 0 0 1 .199.884c-.163.386-.61.58-.964.443-.024-.006-.024-.006-.062-.022l-3.662-1.529.426-.52a3.98 3.98 0 0 0 .636-1.094l.241-.626 3.142 2.424zm1.332-3.303c.053.422-.239.809-.63.87l-.035.006-3.945.508.108-.662a3.999 3.999 0 0 0 .003-1.266l-.105-.663.665.09 3.272.44c.068.012.068.012.052.01a.784.784 0 0 1 .615.667zm-3.894 6.421c.024.068.024.068.017.053a.786.786 0 0 1-.27.87c-.332.25-.816.194-1.047-.091-.022-.023-.022-.023-.05-.058l-2.406-3.154.626-.237a3.977 3.977 0 0 0 1.097-.632l.523-.425 1.51 3.674zm-8.26-4.932c.151.397.365.767.633 1.097l.424.522-.622.256-3.054 1.255a.787.787 0 0 1-.92-.25.781.781 0 0 1-.154-.58c.027-.199.127-.379.227-.452.045-.046.045-.046.075-.069l3.153-2.406.238.627zm3.723 2.572c.209 0 .417-.016.625-.049l.662-.103-.089.664-.438 3.26-.012.062a.785.785 0 0 1-.666.618c-.048.005-.048.005-.101.006-.386 0-.714-.28-.764-.612-.01-.043-.01-.043-.014-.072l-.507-3.934.662.108c.213.035.427.052.642.052zM7.366 18.27l.006-.015L8.9 14.592l.52.426a3.99 3.99 0 0 0 1.094.636l.626.241-.41.531-2.012 2.609-.04.046a.788.788 0 0 1-.886.2.787.787 0 0 1-.428-1.011z">
#      </path>
#      <path d="M11.911 14.322a2.411 2.411 0 1 0 0-4.822 2.411 2.411 0 0 0 0 4.822zm0 2a4.411 4.411 0 1 1 0-8.822 4.411 4.411 0 0 1 0 8.822z">
#      </path>
#     </svg>
#     <div class="DetailsTable--field--3ZKJV">
#      <span class="DetailsTable--label--3Va-t" data-testid="uvIndexTitle">
#       UV Index
#      </span>
#      <span class="DetailsTable--value--1q_qD" data-testid="UVIndexValue">
#       0 of 10
#      </span>
#     </div>
#    </li>
#    <li class="DetailsTable--listItem--2yVyz" data-testid="MoonriseSection">
#     <svg aria-hidden="true" class="DetailsTable--icon--1FR4N Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="moonrise" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#      <title>
#       Moon Rise
#      </title>
#      <path d="M12 17.186c3.59 0 6.5 2.542 6.5 5.678 0 .409-.22.822-.98.822H6.454c-.773 0-.955-.342-.955-.822 0-3.136 2.91-5.678 6.5-5.678zM12.062.202c.291.014.578.133.8.355l4.19 4.19a1.219 1.219 0 11-1.724 1.723l-2.11-2.11v5.438a1.219 1.219 0 01-2.43.124l-.007-.124V4.36L8.672 6.47a1.219 1.219 0 01-1.624.089l-.1-.089a1.219 1.219 0 01-.088-1.625l.089-.099 4.19-4.189c.221-.222.508-.34.799-.355h.124z">
#      </path>
#     </svg>
#     <div class="DetailsTable--field--3ZKJV">
#      <span class="DetailsTable--label--3Va-t" data-testid="MoonriseTitle">
#       Moonrise
#      </span>
#      <span class="DetailsTable--value--1q_qD" data-testid="MoonriseTime">
#       6:58 pm
#      </span>
#      <div class="DetailsTable--moonPhraseWrapper--3mdul">
#       <svg aria-hidden="true" class="DetailsTable--moonIcon--10mco Icon--icon--3wCKh Icon--fullTheme--3ns8p" data-testid="Icon" height="1024" name="phase-16" role="img" set="astro" theme="full" viewbox="0 0 1024 1024" width="1024">
#        <title>
#         Moon Phase - Day 16
#        </title>
#        <path d="M516.262 978.714q173.153 0 297.29-135.06T937.689 517.86q0-190.202-124.137-325.528T516.262 57.006q-190.202 0-325.528 135.326T55.408 517.86q0 190.734 135.326 325.794t325.528 135.06zm0-956.87q204.587 0 350.568 145.981t145.981 350.568q0 205.12-145.981 350.568t-350.568 145.448q-205.12 0-350.568-145.448T20.246 518.393q0-204.587 145.448-350.568T516.262 21.844z">
#        </path>
#       </svg>
#       <span class="DetailsTable--moonPhrase--2WlTc" data-testid="moonPhase">
#        Waning Gibbous
#       </span>
#      </div>
#     </div>
#    </li>
#    <li class="DetailsTable--listItem--2yVyz" data-testid="MoonsetSection">
#     <svg aria-hidden="true" class="DetailsTable--icon--1FR4N Icon--icon--3wCKh Icon--actionTheme--sZu_q" data-testid="Icon" name="moonset" role="img" set="current-conditions" theme="action" viewbox="0 0 24 24">
#      <title>
#       Moon Set
#      </title>
#      <path d="M12 17.186c3.59 0 6.5 2.542 6.5 5.678 0 .409-.22.822-.98.822H6.454c-.773 0-.955-.342-.955-.822 0-3.136 2.91-5.678 6.5-5.678zM12 .2c.631 0 1.15.48 1.212 1.094l.007.125-.001 5.436 2.11-2.109a1.219 1.219 0 011.624-.088l.1.088c.443.445.473 1.146.088 1.625l-.089.099-4.19 4.19c-.19.19-.427.304-.674.342l-.125.013h-.124a1.214 1.214 0 01-.8-.356L6.948 6.47a1.219 1.219 0 111.724-1.724l2.109 2.109V1.419C10.781.746 11.327.2 12 .2z">
#      </path>
#     </svg>
#     <div class="DetailsTable--field--3ZKJV">
#      <span class="DetailsTable--label--3Va-t" data-testid="MoonsetTitle">
#       Moonset
#      </span>
#      <span class="DetailsTable--value--1q_qD" data-testid="MoonsetTime">
#       9:50 am
#      </span>
#     </div>
#    </li>
#   </ul>
#  </div>
# </details>

# %%
period=to_day.find(class_="DailyContent--daypartName--1bzYn").text
temp=to_day.find(class_="DailyContent--temp--3d4dn").text
desc_short=to_day.find(class_="DailyContent--narrative--hplRl").text

print(period)
print(temp)
print(desc_short)
# Out:
# Sun 21 | Night
# 46°
# Mainly clear skies. Low 46F. Winds SSW at 5 to 10 mph.

# %%
period_tags=ten_day.select(".Disclosure--themeList--25Q0H .DailyContent--daypartName--1bzYn")
periods=[pt.text for pt in period_tags]

temp_tags=ten_day.select(".Disclosure--themeList--25Q0H .DailyContent--temp--3d4dn")
temps=[tm.text for tm in temp_tags]

desc_tags=ten_day.select(".Disclosure--themeList--25Q0H .DailyContent--narrative--hplRl")
descs=[ds.text for ds in desc_tags]

# %%
weather=pd.DataFrame({
    "period":periods,
    "temp-F":temps,
    "desc":descs
})
weather
# Out:
#             period temp-F                                               desc
# 0   Sun 21 | Night    46°  Mainly clear skies. Low 46F. Winds SSW at 5 to...
# 1     Mon 22 | Day    61°         Sunny. High 61F. Winds SW at 10 to 15 mph.
# 2   Mon 22 | Night    55°  Considerable cloudiness. Occasional rain showe...
# 3     Tue 23 | Day    59°  Cloudy with periods of rain. High 59F. Winds S...
# 4   Tue 23 | Night    50°  Occasional rain. Low near 50F. Winds NNE at 10...
# 5     Wed 24 | Day    53°  Cloudy with periods of light rain. High 53F. W...
# 6   Wed 24 | Night    48°  Rain showers in the evening becoming more inte...
# 7     Thu 25 | Day    54°  Mostly cloudy. High 54F. Winds NE at 10 to 15 ...
# 8   Thu 25 | Night    45°  Partly cloudy. Low near 45F. Winds E at 5 to 1...
# 9     Fri 26 | Day    58°  Partly cloudy early followed by some light rai...
# 10  Fri 26 | Night    55°  Cloudy with occasional light rain. Low near 55...
# 11    Sat 27 | Day    63°  Rain showers in the morning becoming a steady ...
# 12  Sat 27 | Night    58°  Cloudy with periods of light rain. Low 58F. Wi...
# 13    Sun 28 | Day    63°  Cloudy. Some light rain is likely. High 63F. W...
# 14  Sun 28 | Night    57°  Cloudy with occasional light rain. Low 57F. Wi...
# 15    Mon 29 | Day    64°  Cloudy with periods of light rain. High 64F. W...
# 16  Mon 29 | Night    51°  Rain likely. Low 51F. Winds SW at 15 to 25 mph...
# 17    Tue 30 | Day    57°  Periods of rain. High 57F. Winds WSW at 10 to ...
# 18  Tue 30 | Night    50°  Occasional light rain. Low near 50F. Winds WSW...
# 19    Wed 01 | Day    55°  Cloudy. Some light rain is likely. High near 5...
# 20  Wed 01 | Night    48°  Cloudy with showers. Low 48F. Winds SW at 5 to...
# 21    Thu 02 | Day    55°  Considerable cloudiness with occasional rain s...
# 22  Thu 02 | Night    49°  Cloudy with occasional rain showers. Low 49F. ...
# 23    Fri 03 | Day    55°  Showers early becoming less numerous later in ...
# 24  Fri 03 | Night    48°  Overcast with rain showers at times. Low 48F. ...
# 25    Sat 04 | Day    55°  Rain showers early with some sunshine later in...
# 26  Sat 04 | Night    47°  Mostly cloudy with some showers late. Low 47F....
# 27    Sun 05 | Day    54°  Cloudy with showers. High 54F. Winds N at 5 to...
# 28  Sun 05 | Night    46°  Partly cloudy skies. Low 46F. Winds NNE at 5 t...

# %%
temp_nums=weather["temp-F"].str.extract("(\d+)", expand=False)

# %%
weather["Celcius"]=temp_nums.astype('int')
weather["Celcius"]=transform(weather["Celcius"])

# %%
weather
# Out:
#             period temp-F                                               desc  \
# 0   Sun 21 | Night    46°  Mainly clear skies. Low 46F. Winds SSW at 5 to...
# 1     Mon 22 | Day    61°         Sunny. High 61F. Winds SW at 10 to 15 mph.
# 2   Mon 22 | Night    55°  Considerable cloudiness. Occasional rain showe...
# 3     Tue 23 | Day    59°  Cloudy with periods of rain. High 59F. Winds S...
# 4   Tue 23 | Night    50°  Occasional rain. Low near 50F. Winds NNE at 10...
# 5     Wed 24 | Day    53°  Cloudy with periods of light rain. High 53F. W...
# 6   Wed 24 | Night    48°  Rain showers in the evening becoming more inte...
# 7     Thu 25 | Day    54°  Mostly cloudy. High 54F. Winds NE at 10 to 15 ...
# 8   Thu 25 | Night    45°  Partly cloudy. Low near 45F. Winds E at 5 to 1...
# 9     Fri 26 | Day    58°  Partly cloudy early followed by some light rai...
# 10  Fri 26 | Night    55°  Cloudy with occasional light rain. Low near 55...
# 11    Sat 27 | Day    63°  Rain showers in the morning becoming a steady ...
# 12  Sat 27 | Night    58°  Cloudy with periods of light rain. Low 58F. Wi...
# 13    Sun 28 | Day    63°  Cloudy. Some light rain is likely. High 63F. W...
# 14  Sun 28 | Night    57°  Cloudy with occasional light rain. Low 57F. Wi...
# 15    Mon 29 | Day    64°  Cloudy with periods of light rain. High 64F. W...
# 16  Mon 29 | Night    51°  Rain likely. Low 51F. Winds SW at 15 to 25 mph...
# 17    Tue 30 | Day    57°  Periods of rain. High 57F. Winds WSW at 10 to ...
# 18  Tue 30 | Night    50°  Occasional light rain. Low near 50F. Winds WSW...
# 19    Wed 01 | Day    55°  Cloudy. Some light rain is likely. High near 5...
# 20  Wed 01 | Night    48°  Cloudy with showers. Low 48F. Winds SW at 5 to...
# 21    Thu 02 | Day    55°  Considerable cloudiness with occasional rain s...
# 22  Thu 02 | Night    49°  Cloudy with occasional rain showers. Low 49F. ...
# 23    Fri 03 | Day    55°  Showers early becoming less numerous later in ...
# 24  Fri 03 | Night    48°  Overcast with rain showers at times. Low 48F. ...
# 25    Sat 04 | Day    55°  Rain showers early with some sunshine later in...
# 26  Sat 04 | Night    47°  Mostly cloudy with some showers late. Low 47F....
# 27    Sun 05 | Day    54°  Cloudy with showers. High 54F. Winds N at 5 to...
# 28  Sun 05 | Night    46°  Partly cloudy skies. Low 46F. Winds NNE at 5 t...
#
#       Celcius
# 0    7.777778
# 1   16.111111
# 2   12.777778
# 3   15.000000
# 4   10.000000
# 5   11.666667
# 6    8.888889
# 7   12.222222
# 8    7.222222
# 9   14.444444
# 10  12.777778
# 11  17.222222
# 12  14.444444
# 13  17.222222
# 14  13.888889
# 15  17.777778
# 16  10.555556
# 17  13.888889
# 18  10.000000
# 19  12.777778
# 20   8.888889
# 21  12.777778
# 22   9.444444
# 23  12.777778
# 24   8.888889
# 25  12.777778
# 26   8.333333
# 27  12.222222
# 28   7.777778
